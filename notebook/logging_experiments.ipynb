# %%
print('All ok')
# Out:
# All ok

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), 'logs')

# %%
logs_dir = os.path.join(os.getcwd(), 'logs')
if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# %%
# more concise way to create the directory after checking if it exists
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '07_30_2025_10-14-37.log'

# %%
LOG_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
LOG_PATH
# Out:
# '/Users/ROOPS/Documents/VS-Workspace/LLMOPS/Project1_Document_Portal/notebook/logs/07_30_2025_10-14-37.log'

# %%
logging.basicConfig(
    filename=LOG_PATH,
    level=logging.INFO,
    format="[%(asctime)s] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
)

# %%
logger = logging.getLogger("test_logger").info("This is a test log message.")
